# %%
from keras.models import load_model
from keras.preprocessing import image
import warnings
warnings.filterwarnings(action='ignore')

# %%
model = load_model("skindisease.h5")

# %%
test_image = image.load_img(r"C:\Users\DELL\Desktop\IA_project\dataset\test\Vitiligo\images - 2020-04-26T220059.117.jpg",target_size=(64,64))

# %%
import matplotlib.pyplot as plt
import numpy as np
from keras.preprocessing import image
import numpy as np
plt.imshow(test_image)
plt.show()
import numpy as np
x = image.img_to_array(test_image)
x =np.expand_dims(x,axis=0)
pred = np.argmax(model.predict(x), axis=-1)
pred
index = ['Acne', 'Melanoma', 'Psoriasis', 'Rosacea', 'Vitiligo']
pred_class=index[pred[0]]
pred_class
# Out:
# 'Vitiligo'
